# %% [markdown]
# # Youtube Data API project ✏️

# %% [markdown]
# ##### Inspired by [techTFQ] - “Python Project to Scrape YouTube using YouTube Data API | Analyze and Visualize YouTube data"
#
# ##### --- Project's overview 💡---
# ##### **Object**: To analyze the growth and engagement trends of my favorite artist's Youtube channel over time.
# ##### **Data collection**: I collect the channel's data including general channel details and videos related data from youtube using the Youtube Data API in Python.
# ##### **Data anlysis**: Store the collected data as panda dataframe and convert it to excel file for further analysis in MySQL and perform data visualisation in Tableau

# %% [markdown]
# ### Install relevant packages

# %%
# !pip3 install google-api-python-client pandas
from googleapiclient.discovery import build
import pandas as pd
# Out:
# Requirement already satisfied: google-api-python-client in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.171.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (2.40.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (2.25.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (6.31.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2025.4.26)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
# Retrieve api key from google cloud
api_key = 'AIzaSyDTLp2KLE7NZhLZdd1b6r1xCV4YPaCPnUY'  
# Channel_id for channel 'BUS because of you I shine'
channel_id = 'UC7QNUrXmyiZHgS7Y1U62JFQ'  

# build a youtube service using API key
youtube =build('youtube','v3',developerKey = api_key)

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_channel_stats(youtube, channel_id):
    data_list = []
    request = youtube.channels().list(
        part="snippet, contentDetails, statistics, topicDetails",
        id = "UC7QNUrXmyiZHgS7Y1U62JFQ")
    response = request.execute()

    # Get youtube channel details and store it as a dictonary
    
    data = dict(Channel_name = response['items'][0]['snippet']['title'],
                Subscribers =  response['items'][0]['statistics']['subscriberCount'],
                Views = response['items'][0]['statistics']['viewCount'],
                Total_videos = response['items'][0]['statistics']['videoCount'],
                playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads'],
                published = response['items'][0]['snippet']['publishedAt'])
    data_list.append(data)

    # Return a channel's general details as a dataframe

    return pd.DataFrame(data_list)

# %%
channel_data = get_channel_stats(youtube,channel_id)

# %%
channel_data
# Out:
#                  Channel_name Subscribers      Views Total_videos  \
# 0  BUS because of you i shine      891000  214092731         1285
#
#                 playlist_id                    published
# 0  UU7QNUrXmyiZHgS7Y1U62JFQ  2023-10-27T09:07:46.983554Z

# %%
# Export as a csv file
channel_data.to_csv('bus_channel_dat.csv', index=False, encoding='utf-8-sig')

# %%
# Get channel's playlist id
playlist_id = channel_data.loc[0, 'playlist_id']

# %%
playlist_id
# Out:
# 'UU7QNUrXmyiZHgS7Y1U62JFQ'

# %% [markdown]
# ## Function to get video id

# %%
# Retrieve all videos from the playlists
def get_video_ids(youtube, playlist_id):
    video_ids = []
    next_page_token = None

    while True:
        # Fetch upto 50 videos per page (max)
        response = youtube.playlistItems().list(
            part='contentDetails',
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token
        ).execute()
        
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        # Go through next page until no more pages are available
        next_page_token = response.get('nextPageToken')
        if not next_page_token:
            break


    return video_ids

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['Bph5aWCSLTw',
#  'umpkjQstRgI',
#  'BqdEL7T1-jo',
#  'WBbAN0zetq0',
#  '_eyzcGpXCtM',
#  '1vw9xNGUg_0',
#  '6pQLZLYlb20',
#  'flgl5KjS3Xc',
#  'q9yJlCfwuFY',
#  'SCS7gtU83JY',
#  '577VM54xQlM',
#  'N1wM-VLw6Xs',
#  'YsAeSJx4l5g',
#  '4H8rQ_Lc5xY',
#  'ENiM7BiNsj0',
#  'dZ_ak2VLRaY',
#  'OcZGbef38lw',
#  'ViizgDfgTl4',
#  'XU2nPMm0IEg',
#  'SRnSgaz8LnA',
#  'ekdlNtGzcxM',
#  'lo3vQPhIEHc',
#  'uivGuD8wsXY',
#  'SV6TbZBoLC8',
#  '6YS9_Qy9cJ0',
#  'fSdp1aPWVOM',
#  'auz6R5afWwQ',
#  'vsY0-YlfySs',
#  'Xw4bbwDPI-0',
#  'k_YRs5pcV5c',
#  'cEijoi77ejo',
#  'wtw7OsdtJWY',
#  'RSlEkzvhLYc',
#  'Dd2F5_xnlVM',
#  'EUUrolNNKRI',
#  'SwaikHbeQiw',
#  'XLqhuCUaRWE',
#  'XXroOVb6GH0',
#  'ace4HHOmX94',
#  'oTDxKBqViyU',
#  'SrMntn8Y7ks',
#  'ykceWsxoLO8',
#  'joDfRmLjEDI',
#  'WCVTBi9oOnU',
#  'Oz6O2cPvsh4',
#  'Ef459rNtw_w',
#  'E7OKs-kl8u4',
#  'sXK-QQ-quus',
#  'W3qPsn8wzQM',
#  'tlyxhcUVqfg',
#  'dst0PgF_59Q',
#  '6AjZjcpVBVc',
#  'I7mdKNPE5ps',
#  'v2Lgy5ZcqdU',
#  'x6Y75W8-gyM',
#  '_j6hKkt0xmU',
#  'Fb6aFBgRYtk',
#  'blOhe125T8A',
#  '96OpGMxUSfM',
#  'xbYZX-14P4k',
#  '4W63DnKOjQA',
#  'JtmVZR_hwY0',
#  'nfg3DTOZMlw',
#  'MoYh4Qu1G8I',
#  '6lpmdxaj1Xg',
#  '4SQWcpHbgKQ',
#  'I_Nmum4b9Jo',
#  'vI5UmIYADpg',
#  '5Qdo4JhfQnM',
#  'TpfauZU2_vI',
#  'ulImvB5oZUA',
#  'TNJ36hGdsGw',
#  'wWBFfI08dSI',
#  'n2aySqymyIw',
#  'foNVd0LJZaM',
#  'ASF4v1vAALo',
#  'uIMvi9-j2m4',
#  '72SmMb5_vVw',
#  'UM4Q2tC0iIc',
#  'pjcYNmEAvLg',
#  'jVdy9JUdnTs',
#  'g0OVfODtC2g',
#  'JexmLDgiAp0',
#  '7E73zcEMuYE',
#  's8mZTUhSUNI',
#  'MtrjSSPon98',
#  'JHkO51kKZvU',
#  'a5dqb7alkVU',
#  'WpWGPXirxic',
#  'cAYN2Tl7lek',
#  '-cVfBFM9Lnc',
#  'FsH5mZPm-c0',
#  '0VgBFBTDLGU',
#  'SjXsARWRCBE',
#  '9ypglZHs0Jw',
#  'hkUXECbhrjU',
#  'mmDmAMFX9e4',
#  'YWf3Vw7nQLM',
#  'rPzoLs_sHJE',
#  'ODGakwwO7Wg',
#  'p_iMG4xvXOU',
#  'f1a5rbCRyx8',
#  'FzBWisZfPRI',
#  'ib6LjKORoKc',
#  '_y4r7lToRl4',
#  'H8pZIMHWy3w',
#  'mLkfvmlnUWg',
#  'MgVM71It3s0',
#  'dgG74V6BLTg',
#  '0wdsTEgmgro',
#  'uzvgSG5BbNc',
#  'GRMOJKpNLQs',
#  '-LQYvPNl2lk',
#  'AFsHeF7SKDs',
#  'sT0eu3wcoi8',
#  'D3iwa9NOtKs',
#  'PX9X1l88PjY',
#  'reiy-oud0bo',
#  'EP_U9dzGlMs',
#  'YQGZK4Ttf2U',
#  'u5m999BvOV4',
#  'rhK4jGkfx-M',
#  '3kHFpNS6gEI',
#  'hZgVBZMJzlE',
#  'zV_kHUQbK-0',
#  'r3JMPj9s40Q',
#  'kfObldWh2Qg',
#  'rHLjpzXutME',
#  'z6_9zAazQVE',
#  'rMYMDnRlfyQ',
#  'ik622zlaLtE',
#  'TCv_zjcZtlY',
#  'bjchdSVUKcI',
#  'sJ5vF4Qxf7s',
#  'RmhtrIRMfvY',
#  'JcWfkCMgC4k',
#  'DU_OUUs_WvE',
#  'veJv-WgFh3o',
#  'XXEx-nGXgVQ',
#  '4f_9o596mpA',
#  'adJorg23m0Q',
#  '9QWF53VnTOg',
#  'LPDXX_I4DPM',
#  '5lPFVEfR_ns',
#  'oKxtRY1M_Gw',
#  'vSPcX-FDr4A',
#  'EAu-DcdGxNw',
#  'WklonG8pkH8',
#  'H893xO17KOA',
#  'sYUkH6mJ0Ts',
#  'kHNmb_3BtFM',
#  'tNR-HfW4AZU',
#  '737unuEVX8s',
#  'jhlLfvN2Gmg',
#  'TJTd1toa-5Q',
#  'pHzc28rQer0',
#  'CKdPTFjjE6I',
#  '1E2RkJU-Q-U',
#  'JCpZDyMvS9c',
#  'dWOis2miz8Q',
#  '-nwg3yE_LmM',
#  'BsCh8H00aAg',
#  'QX0mmpRiggw',
#  'mWGNH0xwsyk',
#  'Jks_KVZJXIM',
#  'ZXPhSCihANA',
#  '5g0hfHebPvo',
#  'GB9Xshz6stM',
#  '44GQB-VwnSw',
#  'sU8bMj60xNM',
#  'sKNbgRIEUjw',
#  '5bCC_mqlZoI',
#  'C-VjiMbonv4',
#  'j9Wm2Ls1zqI',
#  'F_3LSW-WPWg',
#  'iMuxcpRBDgM',
#  'bHEvLlwX8wM',
#  'RlFiCMJno8M',
#  '7JdAWfMQEhY',
#  'tCajVop85ZE',
#  'tVj-O6Wl5nw',
#  'Q-CpyYolkhk',
#  'SH5xxlFcf_U',
#  '3zBwbPDEvW4',
#  'z6v4aImUfkg',
#  'MvsKc5FtCN4',
#  'AEdJW1EC4-Y',
#  'r_-FLauPiJ4',
#  '4O_E4ljOpls',
#  'oP7jl2p7dzs',
#  'ndAh1JpewJo',
#  'lFzB0ADN32M',
#  '9a2bYWpNsMs',
#  'qgFbo9SN3dQ',
#  'bBB-h2NjPTk',
#  'weA0MZxmugY',
#  'jm7-RHUpYQM',
#  'FoIXzClUgaI',
#  'U1y0NRWCQKA',
#  'NHST27Mnpfo',
#  'txlvGeLNItU',
#  'nezeWY0jiMw',
#  'OUEh5J-3LUk',
#  'l0k7o_1E728',
#  'NGixHgo8B4o',
#  'LN3j5YdbAd8',
#  'fgMgqfX1YQ8',
#  'vq7SN_-q7kE',
#  'g2XFojV4FOc',
#  'OGiVB8FGK9w',
#  'eaTCH0q0KuI',
#  'hDgbwBWqtRs',
#  'jWVSw1Q3sXs',
#  'dUcslXHlQnY',
#  'QymVdyxFczE',
#  'Qv0rpNHpt78',
#  '9VmV1j89L9E',
#  'c5oKXEMHFf8',
#  '3G0mmpBoI8w',
#  'cHbCJZfiuws',
#  'cjN72jZSgQ0',
#  '5btv4wY8-00',
#  '6nT7t-0bz-4',
#  '8SAYAWO19FQ',
#  '9CAVtqTJm6A',
#  '9o2XJYTSy7Y',
#  '9s0cgnZ7TbY',
#  'BDRxqVzqtLc',
#  'Bs4pd2JcMyc',
#  'C_yxHVUy_64',
#  'DipB7wzpi2c',
#  'GlIqUZKlDqo',
#  'GuT-aHTUnZI',
#  'Run6JR9wjd8',
#  'Sa5g61wGVJY',
#  'Sc2taNiqV7Q',
#  'sMDxDehguHM',
#  'szdXbKjn8zI',
#  'EXaXRyaGJuI',
#  'vEkiVEcJUNI',
#  'eGtOfMFy2z8',
#  'P3e-G0hmRb8',
#  'OhhsrTZX8As',
#  'IcCZKZsHGB0',
#  'LPvZRXMcmcY',
#  'ugoSECUfPFc',
#  'MimrYK2JBT0',
#  'zuu4jcil87M',
#  'Gq4Yen0_XGA',
#  '5cEhHnNQs0I',
#  'sau7lEdS0H4',
#  'K26mvG4vIgM',
#  'xLnMcIRVx_k',
#  'vdMO4qxo538',
#  'poZ4BGaeLZE',
#  'LsUzoqS_5OM',
#  'IIxxeaoghtc',
#  'UKzNOx0pSzk',
#  'wmox3JJDpOI',
#  'izjrhLAgLiI',
#  'VwfsMOBecmg',
#  'vfayv-jYBmw',
#  '9egpx5AgPVE',
#  'SoBXKQsscwM',
#  'TxeSwuuGr-4',
#  'gH4wsqGlA0o',
#  'o65Hzw_jFbM',
#  'DTkAfvd7DDY',
#  'aT2AQB9w8VE',
#  '1reeZ3zMPSQ',
#  'xZ9vpmdQ-mU',
#  'axzXt0WwwPE',
#  'ZrSrD1xp54U',
#  'bBJI8ougq1s',
#  'nPn2yvxEkOM',
#  'VfUxQzvKD1Q',
#  '-5-GGgkjVWk',
#  'wC2_lSak1ZU',
#  'UI9WwPrair0',
#  't_x8ar90YbI',
#  'qrRSNDWu2_0',
#  'TWq0-tsJFvg',
#  'Bh1gbloFr-o',
#  'GcSemtPKgSw',
#  'sIHbWFkFoI8',
#  '7l_w1HHeRpQ',
#  'G7PubIC5RYw',
#  'Bg5e4QnskBU',
#  'yRmI1wex4NM',
#  'gN_-Q0KekSw',
#  'xh40eH_onWA',
#  '7XGl2orqRdI',
#  'J9T37JmCtNw',
#  'JZetPhimdOg',
#  'FYQJzMjxo9o',
#  'ctY4YBJWTuA',
#  'Gchz1Alj5LY',
#  'iLwZbeQtgOU',
#  'UbqGgNCThzU',
#  'Vn4fvGDZiL4',
#  'ivmVzy4-z_w',
#  'UlisJaEhwHQ',
#  'xmsDPEEK3Ek',
#  'bT_pLz4DTnA',
#  'R9gN3YsJXdE',
#  'N3Mkqmqd-BA',
#  'SCbsV7rRLe8',
#  '_qR97WSTYks',
#  'QdnGh2U814E',
#  'HqOEuJBqOOc',
#  '1Iyk-qKXsKQ',
#  'bHfmAUtOHJs',
#  'GvCl3dJpdWs',
#  'SWE4XBrX7_U',
#  'wzyoEcUUVzI',
#  'fBchF2UONes',
#  'ubbNZNrbyCE',
#  'VxtE4pZI4no',
#  '8UK2Z1eVM7Q',
#  'QR4mqneEH7s',
#  'RLlmiJRX5Yg',
#  'Fob8RBox8f8',
#  '2KweFoHt6pE',
#  'HoqWwnD2nZ0',
#  'KDYIAY-V24A',
#  'saHJ6pufALY',
#  'W0H3gMkVt94',
#  '-2-eQncy2a4',
#  '1Z24fk9T9UA',
#  'ULCnOzMY89s',
#  'N8JM5j4P418',
#  'hZDqDx9a-E0',
#  'iRgE97wcRSM',
#  '81RZ3mkpjyI',
#  'Kx8G4io8x3E',
#  'g_KFIQrStRo',
#  'z-hO4BSA2yI',
#  'TD07Zum783E',
#  'tp_JhHFbDnQ',
#  'mxaJxvr-jAY',
#  'XdGof_INC2E',
#  'xbu5_Jg9fSw',
#  'MWY40qSQVSw',
#  'jO1G2xoHuHk',
#  '1A-EXkXhS_w',
#  'sSlW4zUCZvw',
#  'E4HMZYlfQPA',
#  'RxCtp3wmP_g',
#  'Jsw251W5UB0',
#  'wG0l5rLHjTA',
#  'srX0-R21FOw',
#  '6klDLr1NZ4A',
#  'MQVMMQP8VRE',
#  'AkYhTlsm86A',
#  '5XIPz7HBBGI',
#  'Ah5in6mMmLA',
#  'tkvyq9SpplA',
#  '3WPdv52iU54',
#  'Wc6xjtKNuGc',
#  'Nz4O5Wwq19Q',
#  '783dLRwyzM0',
#  'Glqbmx75u7c',
#  'PiJG7w4A8es',
#  'fAIW65msmqM',
#  '-rZVH4UdJvI',
#  'k17g7ORk9sE',
#  'tekaP14G7Oc',
#  'ajfg-WcXNX0',
#  'MCaN9rS-pa0',
#  '0THOCvuhuHc',
#  'REYxbPk8q18',
#  'p8z1MSNcGyA',
#  'Ah5wd2INkzI',
#  'wrKMMQddudg',
#  'UWnW-V1EeWQ',
#  'qItA6nlZlvI',
#  'aumR9Q0p7XM',
#  '-cK4HKqBB5w',
#  'ncpe5OBPgkY',
#  'OG-tppQKZW8',
#  'Irri1JlqAng',
#  'bKe5iRIO6XQ',
#  'JgYEN_h9jvo',
#  'LCAcJ3LmVq0',
#  'CIe-G4zg2gQ',
#  '6QZgA-JpFOA',
#  'sW6mQe49tg0',
#  'Pu0YUGJ6-ZQ',
#  '6p3JHEL4g6Q',
#  'G2ut75Y-sSY',
#  'c2tYiqeVF0I',
#  'rIqAKB24OSc',
#  'aPHj085EhI4',
#  'OLt79-Bnn_Y',
#  'spZV13SfB5Q',
#  '7sErib567H0',
#  'mcg0CBZdXbQ',
#  '_zIJ5DegF2M',
#  'C6G16RPxFOw',
#  'Exnxqm3gCVU',
#  'AmpGYAcoqo4',
#  'q_tiigj2kDk',
#  'MqJkSoQfjUc',
#  'PkPS0HjuUxM',
#  '4S7F1LXdRl4',
#  '0VXHHGAHEEY',
#  'PE65Gnv5riA',
#  '-DeM68HH8NA',
#  'WnEaQrS90KY',
#  'c3i6PGo_yTA',
#  'DyNKORTO8eg',
#  '99ovHqU5Xvg',
#  'WYVjIGRYVEU',
#  'Hpn9FyIOb8I',
#  'iRxJsG7OHfc',
#  'q8hWDxVk2Ps',
#  'BdAb57QVkTw',
#  'DXR27LcU858',
#  '2lIiCGaswDc',
#  'y5CRNigZ4xA',
#  'd9A8GUswHkU',
#  'ARi0rVlwDVU',
#  'jFnzs5-0Gts',
#  'y0cFH079x-k',
#  'oj9n0iu8yeI',
#  'qzDnXZOIy84',
#  'foVvzdYCcsc',
#  '3T074qh57Vg',
#  'ZGOV89bHpKM',
#  'bQo0AxQnwMU',
#  'sknsqgs1qgw',
#  '6lOj76WNuQ4',
#  'sI225xJHELA',
#  '2Dwd3Br5rCc',
#  'cZ8TmEA1YOw',
#  'QhczDsRYlUE',
#  'G0JWSQyOs6U',
#  'B4f1OyF4ts4',
#  'E1QA-ALTjew',
#  'X8PAFLAu3gM',
#  'rc3daMJEYBc',
#  'kazehE1IyXU',
#  'iDf4UTFnm8s',
#  'nOK9A6nCDhM',
#  'IzOuIWoFBPc',
#  '-R_htiKDlzg',
#  '7jHAwu0vZJ0',
#  '5TelZPtDWNk',
#  '_3dn6ouEiHA',
#  '9soIazMY4eE',
#  'Kuf-aZYnwtg',
#  'Go0lRe0Lgtc',
#  'cPUB9AhaBJ8',
#  'a0FVSN8iRlA',
#  'yWgqO_3QMrc',
#  'AmjjAahu06s',
#  '9RzsoBmy6Co',
#  'nEUCRFikFNc',
#  'H1uEWyGWCD4',
#  'J4kjXwqcJVs',
#  'XVuLOXNxAWU',
#  'AiGoPdS5BqA',
#  '9KDE3S8YbvI',
#  'V-9-mUnH5U0',
#  'QOsmBXVXKSQ',
#  'BtcpwGSwfZY',
#  'eyHYF4fbFgA',
#  'y9zgfMOFRzE',
#  'Bdx531LPmts',
#  'Qp4mT5G8RXU',
#  'FLkHmgIrTWM',
#  'TYEQivBoCYM',
#  '4Oy0vs_SIJ8',
#  'eUlgRkRogsQ',
#  '6tlynXfIweQ',
#  '8uW0DlM6Ic4',
#  'kRY_l1HYzLk',
#  'Soij6Tbrfww',
#  'L0HykbsggxI',
#  'G43Fnavku6U',
#  'G9IJQejsQVc',
#  '3nH-tqEojrE',
#  'UYdvxsa9aPM',
#  'afPaJfYMZVI',
#  'X_rs0-qqY5Y',
#  '4k3wG4eTGqQ',
#  'Ox4uXqW030k',
#  'isXnigk3F70',
#  'SFnIXga1j4o',
#  '4Mrif41Q-fQ',
#  'aOAD0dtK234',
#  'b588GcttGEY',
#  '_HIvGGsI2vY',
#  'PGzZxXBHluc',
#  'bdfwX_4sDqk',
#  'e2iq791BP-E',
#  'lvXWBoxWk1w',
#  'cOXRvHseMnU',
#  'bmrnBMxNhZ0',
#  '4NzWBM7tIeE',
#  'yVj8TohCqZQ',
#  'UQkxObk0Ksg',
#  'Ex7TfOT4jW8',
#  'SwOhCoF7LvU',
#  'KE0YSrA-6J0',
#  'OW_ROY5hYeo',
#  'IdSfK2C-7lQ',
#  'I1u-T7I7efA',
#  'xOHFG87W0hs',
#  'Vw5GslCt8dE',
#  'sqj6i6ILt1g',
#  'jJq3GRC0Jd8',
#  'TDPHtzNuH3g',
#  '-2KtvbPQvr8',
#  'ZiXlf7HITyA',
#  'TweayUsiR4s',
#  '9_nYrJZGciM',
#  'Ur0aCiyW3pQ',
#  'atganCG-nfU',
#  'mui8gCOgEMs',
#  'UHWJal95KVM',
#  'coUlr9eKFdU',
#  '5XZGOXVbYzE',
#  'NoNMx3SOfx4',
#  '22IosTbciRg',
#  'iNVU3jDpEe0',
#  'B_F8njjg19Q',
#  'qsp5y51wSRU',
#  'fEsj8xqPWXg',
#  'Ngc29XiJFcg',
#  'LYJrjLknwVg',
#  'bFjgfkggbDs',
#  'q2gDWOJS2KY',
#  'R6NHR02xvpU',
#  'Yh6ERBtz5xc',
#  'oqS468iGT-U',
#  'hmT0Zsk_Res',
#  'Ndy7ox3H6pM',
#  'iMvjMerkcZM',
#  '25EUbHarlLY',
#  '8hkeIyeeZEY',
#  'lQEeBg9oWsQ',
#  'cNwlCPMU7nk',
#  'vj75HeT7Ydg',
#  'I93WKx3bGqc',
#  'qBU7PkkxI8M',
#  'r36SOXA0VPc',
#  'tNC9gNdJm2Y',
#  'OuAclkvIL40',
#  'I7PvAkP-5wI',
#  'Z3_GymT_B_8',
#  'ntjG-1XOpxw',
#  'sYbGnKcYkSw',
#  'tDJ6c46NFa0',
#  '83-TQdBU3MU',
#  '0ZxW9cPqDDU',
#  'lOhSs5zBLTs',
#  'anCl-klxfBk',
#  'ZSMrcuoJYa8',
#  'W6Ca72u31k4',
#  'x_uoFLHgfkk',
#  'MkCJ34WEjHI',
#  'x-iz08vPZMI',
#  'WDtCJYJ8ICQ',
#  'KGKjV9Bwlnk',
#  'H71YGAPmTJA',
#  '0c5C2e2GEBk',
#  'ur8BvdlGYU8',
#  'GBtaNkOU3pk',
#  'poCm15vySDc',
#  'qJSkYo3cn9U',
#  'ITrZ2cr9zac',
#  '-4TNyr79mPE',
#  '-9hhaM2Kbks',
#  'E1OLY6WDr7c',
#  's5IeHcj0_uI',
#  'YszYFUuN5Xg',
#  '5Brf7vCIK9A',
#  'fb1yDhbIMlE',
#  'xhUdcb99Xx4',
#  'YZp-kVt_VGY',
#  'HkshzezD1SI',
#  'IJgDXudiLN4',
#  '3nfg54WNkX0',
#  'K9Z8E276wfI',
#  'jyEpo1eDjp8',
#  'tO4HLnMy1AQ',
#  'VvbxgiUPCto',
#  'mjwg8uX-p-U',
#  'xlmxUf4bnw0',
#  'qQJdLu0qQ44',
#  'EQgMvdUPvhk',
#  '349YGjFIOss',
#  'qg5Ymz4_tEY',
#  '_CJX0jWSBks',
#  'MRpcIY4uGv8',
#  'CdqoYBxGBXY',
#  'JwWLuuzMXMQ',
#  'Di2hAUQDCKo',
#  'hAXwjlkHJiY',
#  'sywHDzHqpJE',
#  'qNbUOBGYAGI',
#  'OMO_2KTp7_w',
#  'n0aySj6Mk0c',
#  'mchB6wA8A3w',
#  'cP8ePawqFvA',
#  '5rFGnIQXvHU',
#  'IzLTH_BvOCs',
#  'MA-hn9BAOb4',
#  'krhCCmGAxh8',
#  'c-m7PkhEHoc',
#  'YfrXQ-8WAew',
#  '6jcEiWnCpoE',
#  'G5MPR31QsaI',
#  '_aSxDuzQdN0',
#  'P9osSUabN5w',
#  'RGKSE43rVQQ',
#  'tPhLhYrDlnM',
#  '7fW08KSSsFI',
#  'zt42SlS-t4c',
#  '2WUqjhLhBbk',
#  '1GdlUy1Z11I',
#  '6UOBYARMsJg',
#  '8mf1JLvOJIw',
#  'T2ce-YVGJ8g',
#  'JFsS2mbyp-k',
#  'uDqxAAtjdPo',
#  'qaxSgzPeU9I',
#  'mwf-hN125Os',
#  'c5nKup9rdmM',
#  'Pgj2Q4ztaMk',
#  'AkDsR2wdBqc',
#  '7ZMPdUirzD8',
#  '5PUaDo29JvE',
#  'EVt9YDCHjAI',
#  'HhjG4PeNrFA',
#  '_tDMszDkKSE',
#  'i3FwRvCZ-BM',
#  'lJktL2FevlM',
#  'zsTtaEzYXS0',
#  'm_W7vEBLcfY',
#  'UOUKqipFF14',
#  'eHI69vUoZAY',
#  'BXGqUPtx8PM',
#  'h9Se2okBEPY',
#  '_e_9-wHI7hY',
#  'akzvuHaMOf4',
#  'xhkCWC2eUs4',
#  'gYFSPZ3rjVE',
#  'eHusdvwRt_Q',
#  '0XFPLnYJJfk',
#  'zJwDOLeiaWs',
#  'RJAYn6d0rR4',
#  'AXwUytwAz4Q',
#  'KJYDqFEySBU',
#  '1YnFITvBkss',
#  'xCV1AOoarck',
#  'JU3uDw-kPV8',
#  '20C4Ulnul4g',
#  'HMWXXC4HrP4',
#  '2F8MjfINR9w',
#  '4wnep2TSryI',
#  'oDxp2NWAoWQ',
#  'oWs-Q8PnQFU',
#  '9_8BT55VeWM',
#  'Qzqy6R8XX9g',
#  'SikoeYMt5sg',
#  'WjHNFjuhDT0',
#  'rMYQhfOj4B0',
#  'wKHN25KyqaE',
#  '46lGkh_zYlw',
#  'iCFU7UMtgYI',
#  'aEhtWZsPsZ8',
#  'GdLSkDNPbx4',
#  'MNGUTB5dEDE',
#  'dF7oIgJ8pGU',
#  'SY2noqaDB-c',
#  'zJ7Uglio07w',
#  'ngZxHlkAi7U',
#  'JQgg3AXhm4Q',
#  'fBNx6Dv1SRo',
#  'xHleH6CqBs0',
#  '4Xfz0E9ZZf0',
#  'hHKJCtzP95Q',
#  'hBsg3gsUYwU',
#  'dPv7-9mu2qA',
#  'MZmNbGOaT0M',
#  'e1sZ2TvqwaU',
#  'F8KPzjdVvng',
#  'dQb7YcT8ZgE',
#  'pqI9rfjUOpo',
#  'AVGoaj-3dDY',
#  '-Gb6oiNxQrU',
#  'aicYOS3EsWA',
#  '035S_r9WY5I',
#  'spBgKsrbwPc',
#  'JC2S5fGxG3A',
#  'pXg4_vP1lLQ',
#  'wG_sVYNN2Kc',
#  '-zPY8qb-9KA',
#  'KhYG5A24iss',
#  '9PHljSwdYv0',
#  'XtZCrUE4Sww',
#  'EXi6WBhkiiU',
#  't45aBJa7mPk',
#  'B_LNohb7b04',
#  'PiyBVlqlLTE',
#  'xUe0paUuGfI',
#  'C2W3AxeCw2Y',
#  'wZ5wm0-fzvQ',
#  'JqYtRDomq_c',
#  'jkNpJWg6Vlk',
#  'uLHPi9Vcanc',
#  'fqwCaLW6jYU',
#  'Pj4ch1DqtEc',
#  'uqZEcK6DZeQ',
#  'm2MaE2NAzO4',
#  'MXCBwkUU8Y4',
#  'iWT8rsZy30E',
#  'g_w8BcnPK7Q',
#  'a-gOZhDHOSw',
#  'nYWHdpEV1Rw',
#  'SdUVkPCubYo',
#  '15fvZiSO__Y',
#  'eD-jhhyCBmk',
#  'T8gU9uzkVTQ',
#  'CU5H-jJm9Ms',
#  '8n46OIbmUnI',
#  '01YogFOTotM',
#  '5JVJ4Cli60M',
#  'pWmzbGvaANE',
#  'uX8BH6HPt5o',
#  'pQwqovAbHp0',
#  'urgCQyi2Kuk',
#  'lsa0LAcCERs',
#  'eEq_6nDbATA',
#  'ZH15LO5DgCo',
#  'vO0tk9eTxoo',
#  'Qn3WTeHf1QA',
#  '5Z1GWnm_n7Y',
#  '2I3kKxhON_c',
#  '0LSeu1FfGtI',
#  '2mR8I3sm7gQ',
#  '0o2OaWQIbmc',
#  'aT5hyWb2eS0',
#  '0K8fj0ogpfY',
#  '03wr4W77l2A',
#  'kSqjUyf2lg0',
#  '46QcOnjecp8',
#  'kpmBJ8kX_dw',
#  'EGAHbaJnv0o',
#  'iLXCe28U6Nw',
#  '4rrAUeVyi4w',
#  'Lu4cYaSqiCs',
#  '50GNc5CimTk',
#  'IbqsUP058wg',
#  'OcAxHyQ7zLU',
#  '3yJ-9kwyE84',
#  '7k8hW_58Pio',
#  'K7srwWePcfA',
#  'luZo44WU6yw',
#  'NM2Y7QH2XAA',
#  '_uUOoRrpdX0',
#  's9B82acp1Lo',
#  'c9s3MlJaqjg',
#  'NxSJRlQP2LA',
#  '0bWaZSDjgqg',
#  'gdWADf0XLJs',
#  '-Bw1oHljwAM',
#  '2xKc6xgWDr4',
#  'fjnoTm7aF3s',
#  'SP159P-JsoY',
#  'Li-2d7l1qIo',
#  'RawRpMoCsh0',
#  'Q-GU1FXYOrY',
#  '4mM2QtpEdSs',
#  'JIhYF2wI9Xo',
#  'Idnb8vbfmxs',
#  'AGMTqPoGg-o',
#  'YhBR4sVBh-4',
#  'DM5PTuWqhUA',
#  'Ag2eBZ_r3OQ',
#  'CbaZfveVK1I',
#  'GKw9T6VMlWk',
#  '0RpFA_Rmy8I',
#  'TTQIBvapd-U',
#  'xAd16tXMc5E',
#  'QOdroG49nmI',
#  'a2grzW8Bd4U',
#  'vh0ewNeGuY4',
#  'q3pKGAvJY68',
#  'IJtJF5IyoYQ',
#  'kFYdgzppVd0',
#  '_WGp_hmn5_0',
#  'pILxSSm9ncA',
#  'UkPbvVv0mAw',
#  'Aq1Qm52CsEY',
#  'vgMvm3RS5jQ',
#  'bkHRB8iXzPY',
#  'laVl1Y3fjok',
#  '5uov2EMqHns',
#  'E_-gqsDJlC8',
#  'BbafOfQx1b0',
#  'Wr4HrF9M2Io',
#  'BjZWbQ5AYQQ',
#  'hxQs2XE1nxA',
#  '9I-qnraZgP4',
#  'ps2oFJYRKhQ',
#  'x7xnyNQY-YE',
#  'v_KzC6-hvfA',
#  '-bYmE5obsHQ',
#  '8pEfvfMXHC0',
#  'UtJ9GY7cQOA',
#  'G_SDw6UXDIQ',
#  'HZ8qhYTd8yM',
#  'H7H5yHh7Fqk',
#  'ZRBbau9CdO8',
#  'O9ft6_H5Pfs',
#  'ce64jzDof2A',
#  '7u6eCCvkak4',
#  'zoOEmxD10Co',
#  'AS2Y0U_FBDQ',
#  'cYQoqqmRWwM',
#  'adiGS-W2xr8',
#  'niLZBX59hZw',
#  'B3qeueUGPpk',
#  'FV-o5iSoElg',
#  'gSntrRsH3iU',
#  'OlWIIDkWUbg',
#  '4r9YzeO-AVQ',
#  '6MijqEIqUJo',
#  'dcHtGPRMiIM',
#  'gmqan4GXY1s',
#  '0yWdw1FZ8Yo',
#  'p9aJl6Ns9OU',
#  'xzr5tWxJ2fc',
#  '9cQygnRmvv8',
#  'vIlM38NNT_8',
#  '68TuyH-3cyU',
#  'jU-EFymyXDY',
#  'qO9ZbofbomI',
#  'djkZtpO33So',
#  '-G2n2W8Et9k',
#  't2H23y9E7FY',
#  'fTnmMporJkM',
#  'WKd4anhbJbU',
#  'flztBBKDZ4Y',
#  'fZjBtHCVzXc',
#  'f3zqGU-1K2g',
#  'PKtzRU-piLI',
#  'I0WcW3vMF-k',
#  '16VOFj-TKk0',
#  'oYt3_xeG9sM',
#  'J6jPI5wlcYA',
#  'KouKX6ps8II',
#  'gdmuUD6tP24',
#  'iEZGgO0y4u4',
#  'Xf5LrQZW5hI',
#  'Uw-qBtloYyE',
#  'Ew4Pl2eAPsA',
#  'eTPA07o3wHQ',
#  'vsQfl3pht-Q',
#  'H_rUTvXVa-o',
#  'KFIYwVhIGHM',
#  'EUhLejTNky0',
#  'y16-YlI8BUo',
#  'sZ4OmjM6NSE',
#  'c4cZsdo00oc',
#  'iK0HMAFRQxE',
#  'm_cFoiNmnzk',
#  'HSJpcz2kS9M',
#  'AOsqTICdWV4',
#  '_P3epYGDesU',
#  'p4ZrvwW-tek',
#  '3QZIzqZdD78',
#  '2bIWjxC5oA0',
#  'X1wUpqzdMok',
#  'f3Z4-ypWxss',
#  'Jz5OOezrEHc',
#  '3VXv03RUFno',
#  'jl8BzlE5sfU',
#  '3-BoAFdX_yE',
#  '4bVv1Yfxk0I',
#  '989c2Ku_njM',
#  '2WE9ypqv5P4',
#  'lR1xKFxQSG0',
#  'ds_kQZzoRTk',
#  '9gJDIjyR_Ls',
#  'aF4F9IMAJ8c',
#  'VABJmGY5aEg',
#  'jQznV5ucf7Y',
#  'oMoAVYUn_AM',
#  'matO_i2WiXk',
#  'Xhj4w5CEt20',
#  'VN9JrRMTHyg',
#  'nWff_k61KrY',
#  'AQ-7K2eKBzI',
#  'sikvGy3siB4',
#  'mLX6dmC0ihQ',
#  'QXN-3l1WvEo',
#  'jdK5LT5SrNg',
#  'xHgviFdSw1Y',
#  'jcJBJFrRgh8',
#  'NyHBtQf-1U0',
#  'glo6LI5Zdek',
#  'zWhhLBuiyK0',
#  'MXxoYKw4UZY',
#  '-JzJDWTak70',
#  'lp1wcryZQUA',
#  '3ObLmdMkt7c',
#  'xifPOZ732MY',
#  'jNF6tYU0nTQ',
#  'nsUOzqe4sqY',
#  'M_bgc_KWJKI',
#  'FqfNgznNBOg',
#  'RJra555ssY0',
#  'YQ2UsASrbK0',
#  '3pqSEJqcBZY',
#  'PHuh3C0Uir4',
#  'vZrf0qyoqJ8',
#  'AXwG8cWkQKg',
#  'uFJ6Y0KEsQI',
#  '9IgD0k1d-_U',
#  'hPKhVjuXRUU',
#  'pXGKpiLuOeY',
#  'dZMZrcD9rpw',
#  'Apm7CeWwZTk',
#  'PieJK2ZACCc',
#  '9iXlv8xxlVQ',
#  '_0KAbTfpct4',
#  'zErG1WnHaOU',
#  'xESNPv9t60k',
#  'fUgHalD5nTY',
#  '5gK5iDAb-M8',
#  'GxTcnRyHT70',
#  '5UL1tlIoPvk',
#  'Wcp2gfuZFRc',
#  'IXzQLYRH86s',
#  'kN_R7DjeWPc',
#  'HwcSy5OwP8E',
#  '__8Sig00Zko',
#  'ZBbPLBeBEZo',
#  '3_EOTR2HsfA',
#  'i_JHgRuQe0M',
#  'vmsYSC2_2Z0',
#  'iWX1g3c2Hvw',
#  'VfORYJXsWds',
#  '8LqeFcohgt4',
#  'Q2iJLTPO0bs',
#  '5J6n4_ZRZVk',
#  'pT3crAvpl6A',
#  '7BYRi9xgzWI',
#  '0O2lSC4tvxU',
#  'UX_SY5ATb-w',
#  'KDQPT3CtFXE',
#  'qWcJ1HYoRQY',
#  'o-4868IDYoM',
#  'L41GCiTvDW4',
#  'qiu6FvD8JSw',
#  'dwTPBBb3z6g',
#  'kvPogYvHLm8',
#  '338XY9ocxgU',
#  'dGRVjh0rifY',
#  '7fhRbliqF7w',
#  'v9Iwzk3M3hI',
#  'LQJr8gGsrEw',
#  'QhpsdxKkDyU',
#  'EbBBq9TlQIk',
#  'kTf4xFumI70',
#  'M6zReaBXp9Y',
#  'YLONRUU8IlU',
#  'ndfK59chhVc',
#  'kDguBtZSn3A',
#  'AtWbqXdZmMM',
#  'YS4GDJNgBlU',
#  '6V-E2xgeyjw',
#  'Czis_yvlvvo',
#  'fAYOlLEqoB0',
#  'MXotuU9Oges',
#  'vU7napUJErs',
#  'nqVV3sTUJzM',
#  'rX34JbwMS1s',
#  'uuaBVKEabek',
#  '59gz-kEXU2g',
#  'n_0Qa53l8WQ',
#  'J-T8HPpjbbY',
#  'Y5H89y_2yHY',
#  'NLf_Iz_B4mQ',
#  'V_9J9qxXiXE',
#  'zD16897e-P8',
#  'GS0_bTpPRPk',
#  '-1pP8VNDVBk',
#  'qE0BXBRl2ec',
#  '7eNXT5Otrh0',
#  'FqP79in0oCY',
#  'rcGJUbFRNyU',
#  'BUO_wvqNEDw',
#  'z4QLB2HhOS8',
#  'EdA4Rvkd-sM',
#  'qQZ_eJ0ExrY',
#  ...]

# %% [markdown]
# ## Function to get video details

# %%
# Retreive details for each in a list of video id
def get_video_details(youtube, video_ids):
    all_video_stats = []

    # Process each time with 50 video ids
    for i in range(0, len(video_ids),50):
        request = youtube.videos().list(
            part ='snippet,statistics',
            id = ','.join(video_ids[i:i+50]))
        response = request.execute()

        # Parse each video in the respose
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               published_date = video['snippet']['publishedAt'],
                               views = video['statistics']['viewCount'],
                               like = video['statistics']['likeCount'],
                               Comments = video['statistics']['commentCount'])
            all_video_stats.append(video_stats)
        
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
# Export as csv file
video_data.to_csv('bus_youtube.csv', index=False, encoding='utf-8-sig')

# %%
video_data
# Out:
#                                                   Title        published_date  \
# 0              [VLOG] BUS - บัสเสิร์ฟ เนสท์เล่เพียวไลฟ์  2025-06-07T11:59:00Z
# 1     ⏰ 4PM POV ‘แค่น้องชาย (brother zone)’ #BECAUSE...  2025-06-07T09:01:14Z
# 2     I know bro 🙂‍↕️🙂‍↕️ #THAIchayanon #PHUTATCHAI ...  2025-06-07T05:00:08Z
# 3          [VLOG] BUS COPPER - น้องชายคนใหม่ของคอปเปอร์  2025-06-06T11:59:00Z
# 4     ✨🕺🏻🕺🏻 with p’ #NONTTANONT #AAashirakorn#BUSbec...  2025-06-06T09:01:03Z
# ...                                                 ...                   ...
# 1280  [VLOG] BUS – VLOG แรกของพวกเรา BUS พาไปพบความส...  2023-11-19T12:00:48Z
# 1281  โอ้ว นี่ นะคะ! 👀✨ #นี่นะคะchallenge #BUSbecaus...  2023-11-19T05:20:45Z
# 1282  ZiGZaG and Go on the trip with @allynitibhon  ...  2023-11-12T05:00:30Z
# 1283                 #BUSbecauseofyouishine @ #ICONSIAM  2023-11-11T08:12:21Z
# 1284  ‘BUS’ because of you i shine #BUSbecauseofyoui...  2023-11-08T17:31:10Z
#
#        views   like Comments
# 0      17973   3158      306
# 1      19612   1755       43
# 2      25004   2108       54
# 3      84471   7566      690
# 4      32409   2531       62
# ...      ...    ...      ...
# 1280  170332  10004      432
# 1281   22233   2679       23
# 1282  344650  36496      143
# 1283   15639   1656       18
# 1284   25598   2179       22
#
# [1285 rows x 5 columns]
